# %% [markdown]
# # Task 02 - Track A: Working with DataFrames
#
# **Course:** Database Applications Development
# **Lesson:** 02 - Working with DataFrames (Preparing for SQL)
#
# ---
#
# ## Instructions
#
# Complete all exercises in this notebook. Each section includes example code to help guide you.
#
# **Submission:**
# 1. Save this notebook as `dbAppsTask02TrackA.ipynb`
# 2. Add, commit, and push to your `databaseApplications` repository on GitHub
# 3. Verify the file appears correctly on GitHub
#
# ---

# %% [markdown]
# ## Setup: Load the Dataset

# %%
# Import pandas and load data
import pandas as pd

titanic = pd.read_csv('Titanic Dataset.csv')

# Quick check
print(titanic.shape)
titanic.head()
# Out:
# (1309, 14)
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#      age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.00      0      0   24160  211.3375       B5        S    2    NaN
# 1   0.92      1      2  113781  151.5500  C22 C26        S   11    NaN
# 2   2.00      1      2  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.00      1      2  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.00      1      2  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest
# 0                     St Louis, MO
# 1  Montreal, PQ / Chesterville, ON
# 2  Montreal, PQ / Chesterville, ON
# 3  Montreal, PQ / Chesterville, ON
# 4  Montreal, PQ / Chesterville, ON

# %% [markdown]
# ---
#
# ## Part 1: Selecting Columns

# %% [markdown]
# ### Example: Select a Single Column

# %%
# Select one column (returns a Series)
names = titanic['name']

# Display first 10 values
print(names.head(10))

# This gets just the 'name' column from the titanic DataFrame
# Out:
# 0                      Allen, Miss. Elisabeth Walton
# 1                     Allison, Master. Hudson Trevor
# 2                       Allison, Miss. Helen Loraine
# 3               Allison, Mr. Hudson Joshua Creighton
# 4    Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# 5                                Anderson, Mr. Harry
# 6                  Andrews, Miss. Kornelia Theodosia
# 7                             Andrews, Mr. Thomas Jr
# 8      Appleton, Mrs. Edward Dale (Charlotte Lamson)
# 9                            Artagaveytia, Mr. Ramon
# Name: name, dtype: object

# %% [markdown]
# ### Exercise 1.1: Select Single Columns
#
# Select and display the first 10 values:
# 1. The 'age' column
# 2. The 'fare' column

# %%
age_col = titanic['age']
print(age_col.head(10))
# Out:
# 0    29.00
# 1     0.92
# 2     2.00
# 3    30.00
# 4    25.00
# 5    48.00
# 6    63.00
# 7    39.00
# 8    53.00
# 9    71.00
# Name: age, dtype: float64

# %%
# Fare column
fare_col = titanic['fare']
print(fare_col.head(10))
# Out:
# 0    211.3375
# 1    151.5500
# 2    151.5500
# 3    151.5500
# 4    151.5500
# 5     26.5500
# 6     77.9583
# 7      0.0000
# 8     51.4792
# 9     49.5042
# Name: fare, dtype: float64

# %% [markdown]
# ### Example: Select Multiple Columns

# %%
# Select multiple columns (note the double brackets)
subset = titanic[['name', 'age', 'sex']]

# Display first 5 rows
print(subset.head())

# The outer brackets mean 'select from titanic'
# The inner brackets are a list of column names
# Out:
#                                               name    age     sex
# 0                    Allen, Miss. Elisabeth Walton  29.00  female
# 1                   Allison, Master. Hudson Trevor   0.92    male
# 2                     Allison, Miss. Helen Loraine   2.00  female
# 3             Allison, Mr. Hudson Joshua Creighton  30.00    male
# 4  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  25.00  female

# %% [markdown]
# ### Exercise 1.2: Select Multiple Columns
#
# Create a DataFrame called `passenger_info` with these columns: 'name', 'sex', 'age', 'survived'
#
# Display the first 10 rows.

# %%
# Your code here
passenger_info = titanic[['name', 'sex', 'age', 'survived']]
print(passenger_info.head(10))
# Out:
#                                               name     sex    age  survived
# 0                    Allen, Miss. Elisabeth Walton  female  29.00         1
# 1                   Allison, Master. Hudson Trevor    male   0.92         1
# 2                     Allison, Miss. Helen Loraine  female   2.00         0
# 3             Allison, Mr. Hudson Joshua Creighton    male  30.00         0
# 4  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female  25.00         0
# 5                              Anderson, Mr. Harry    male  48.00         1
# 6                Andrews, Miss. Kornelia Theodosia  female  63.00         1
# 7                           Andrews, Mr. Thomas Jr    male  39.00         0
# 8    Appleton, Mrs. Edward Dale (Charlotte Lamson)  female  53.00         1
# 9                          Artagaveytia, Mr. Ramon    male  71.00         0

# %% [markdown]
# ---
#
# ## Part 2: Filtering Rows

# %% [markdown]
# ### Example: Basic Filtering

# %%
# Filter to get only first class passengers
first_class = titanic[titanic['pclass'] == 1]

# Count how many
print(f"First class passengers: {len(first_class)}")

# Display first few
print(first_class[['name', 'pclass', 'fare']].head())

# The condition titanic['pclass'] == 1 creates True/False for each row
# The brackets filter to keep only True rows

# %% [markdown]
# ### Exercise 2.1: Filter by Survival
#
# Create a DataFrame called `survivors` with only passengers who survived.
#
# Print how many survivors there were.

# %%
# Your code here
survivors = titanic[titanic['survived'] == 1]

print("Number of survivors:", len(survivors))
# Out:
# Number of survivors: 500

# %% [markdown]
# ### Exercise 2.2: Filter by Gender
#
# Create a DataFrame called `females` with only female passengers.
#
# Print how many there were.

# %%
# Create a DataFrame with only female passengers
females = titanic[titanic['sex'] == 'female']

# Print how many there were
print("Number of female passengers:", len(females))
# Out:
# Number of female passengers: 466

# %% [markdown]
# ### Exercise 2.3: Filter by Class
#
# Create a DataFrame called `first_class` with only first class passengers.
#
# Print how many there were.

# %%
# Your code here
# Create a DataFrame with only first class passengers (pclass == 1)
first_class = titanic[titanic['pclass'] == 1]

# Print how many there were
print("Number of first class passengers:", len(first_class))
# Out:
# Number of first class passengers: 323

# %% [markdown]
# ### Exercise 2.4: Filter by Age
#
# Create a DataFrame called `children` with passengers 12 or younger.
#
# Print how many there were.

# %%
# Your code here
# Create a DataFrame with passengers 12 or younger (age <= 12)
children = titanic[titanic['age'] <= 12]

# Print how many there were
print("Number of children (12 or younger):", len(children))
# Out:
# Number of children (12 or younger): 94

# %% [markdown]
# ---
#
# ## Part 3: Sorting Data

# %% [markdown]
# ### Example: Sort by Column

# %%
# Sort by age (youngest first - ascending is default)
sorted_by_age = titanic.sort_values('age')

# Display name and age for first 10
print(sorted_by_age[['name', 'age']].head(10))

# For descending (oldest first), use ascending=False
sorted_desc = titanic.sort_values('age', ascending=False)

# %% [markdown]
# ### Exercise 3.1: Sort by Age
#
# Sort passengers by age and display name and age for the 10 youngest.

# %%
# Your code here
# Sort by age (ascending)
youngest_passengers = titanic.sort_values('age')

# Display name and age for the first 10
print(youngest_passengers[['name', 'age']].head(10))
# Out:
#                                          name   age
# 763   Dean, Miss. Elizabeth Gladys "Millvina"  0.17
# 747   Danbom, Master. Gilbert Sigvard Emanuel  0.33
# 1240          Thomas, Master. Assad Alexander  0.42
# 427                 Hamalainen, Master. Viljo  0.67
# 1111           Peacock, Master. Alfred Edward  0.75
# 657                    Baclini, Miss. Eugenie  0.75
# 658             Baclini, Miss. Helene Barbara  0.75
# 359             Caldwell, Master. Alden Gates  0.83
# 611                 Aks, Master. Philip Frank  0.83
# 548           Richards, Master. George Sibley  0.83

# %% [markdown]
# ### Exercise 3.2: Sort by Fare
#
# Sort passengers by fare (highest first) and display name and fare for the top 10.

# %%
# Your code here
# Sort by fare (highest first)
expensive_fares = titanic.sort_values('fare', ascending=False)

# Display name and fare for the top 10
print(expensive_fares[['name', 'fare']].head(10))
# Out:
#                                                   name      fare
# 183                             Lesurer, Mr. Gustave J  512.3292
# 302                                   Ward, Miss. Anna  512.3292
# 49                  Cardeza, Mr. Thomas Drake Martinez  512.3292
# 50   Cardeza, Mrs. James Warburton Martinez (Charlo...  512.3292
# 113                         Fortune, Miss. Mabel Helen  263.0000
# 114                     Fortune, Mr. Charles Alexander  263.0000
# 115                                  Fortune, Mr. Mark  263.0000
# 116                Fortune, Mrs. Mark (Mary McDougald)  263.0000
# 111                     Fortune, Miss. Alice Elizabeth  263.0000
# 112                         Fortune, Miss. Ethel Flora  263.0000

# %% [markdown]
# ---
#
# ## Part 4: Statistics

# %% [markdown]
# ### Example: Calculate Statistics

# %%
# Calculate average age of all passengers
avg_age = titanic['age'].mean()
print(f"Average age: {avg_age:.1f} years")

# Find the maximum fare
max_fare = titanic['fare'].max()
print(f"Highest fare: ${max_fare:.2f}")

# Other statistics methods:
# .min() - minimum value
# .max() - maximum value
# .mean() - average
# .median() - middle value
# .sum() - total

# %% [markdown]
# ### Exercise 4.1: Overall Statistics
#
# Calculate and print:
# 1. Average age
# 2. Average fare
# 3. Maximum fare
# 4. Minimum age

# %%
# Your code here
# Calculate and print statistics
avg_age = titanic['age'].mean()
avg_fare = titanic['fare'].mean()
max_fare = titanic['fare'].max()
min_age = titanic['age'].min()

print(f"Average age: {avg_age:.1f} years")
print(f"Average fare: ${avg_fare:.2f}")
print(f"Maximum fare: ${max_fare:.2f}")
print(f"Minimum age: {min_age:.1f} years")
# Out:
# Average age: 29.9 years
# Average fare: $33.30
# Maximum fare: $512.33
# Minimum age: 0.2 years

# %% [markdown]
# ### Example: Statistics on Filtered Data

# %%
# Filter first, then calculate statistics

# Get all survivors
survivors = titanic[titanic['survived'] == 1]

# Calculate average age of survivors
avg_survivor_age = survivors['age'].mean()
print(f"Average survivor age: {avg_survivor_age:.1f}")

# Or do it in one line:
avg_age = titanic[titanic['survived'] == 1]['age'].mean()

# %% [markdown]
# ### Exercise 4.2: Statistics on Filtered Data
#
# Calculate:
# 1. Average age of survivors
# 2. Average fare of first class passengers

# %%
# Your code here
# 1. Average age of survivors
survivors = titanic[titanic['survived'] == 1]
avg_survivor_age = survivors['age'].mean()
print(f"Average survivor age: {avg_survivor_age:.1f} years")

# 2. Average fare of first class passengers
first_class = titanic[titanic['pclass'] == 1]
avg_first_class_fare = first_class['fare'].mean()
print(f"Average 1st class fare: ${avg_first_class_fare:.2f}")
# Out:
# Average survivor age: 28.9 years
# Average 1st class fare: $87.51

# %% [markdown]
# ---
#
# ## Part 5: Value Counts

# %% [markdown]
# ### Example: Count Values

# %%
# Count how many passengers in each class
class_counts = titanic['pclass'].value_counts()
print(class_counts)

# Output shows:
# 3    709  (709 passengers in 3rd class)
# 1    323  (323 passengers in 1st class)
# 2    277  (277 passengers in 2nd class)

# value_counts() shows each unique value and how many times it appears

# %% [markdown]
# ### Exercise 5.1: Count Values
#
# Use `.value_counts()` to find:
# 1. How many in each class
# 2. How many male vs female
# 3. How many survived vs died

# %%
# Class counts
class_counts = titanic['pclass'].value_counts()
print("Passengers per class:")
print(class_counts)
# Out:
# Passengers per class:
# pclass
# 3    709
# 1    323
# 2    277
# Name: count, dtype: int64

# %%
# Gender counts
gender_counts = titanic['sex'].value_counts()
print("\nMale vs Female counts:")
print(gender_counts)
# Out:
# Male vs Female counts:
# sex
# male      843
# female    466
# Name: count, dtype: int64

# %%
# Survival counts
survival_counts = titanic['survived'].value_counts()
print("\nSurvived (1) vs Died (0):")
print(survival_counts)
# Out:
# Survived (1) vs Died (0):
# survived
# 0    809
# 1    500
# Name: count, dtype: int64

# %% [markdown]
# ---
#
# ## Part 6: Analysis Questions

# %% [markdown]
# ### Question 1: Survival Rate
#
# What percentage of passengers survived?

# %%
# Your code here
survival_rate = titanic['survived'].mean() * 100
print(f"Survival Rate: {survival_rate:.2f}%")
# Out:
# Survival Rate: 38.20%

# %% [markdown]
# **Answer:**

# %% [markdown]
# ### Question 2: Class Distribution
#
# Which class had the most passengers?

# %%
# Your code here
print(titanic['pclass'].value_counts())
# Out:
# pclass
# 3    709
# 1    323
# 2    277
# Name: count, dtype: int64

# %% [markdown]
# **Answer:**

# %% [markdown]
# ### Question 3: Age Comparison
#
# What was the average age of first class vs third class passengers?

# %%
# Your code here
avg_age_1st = titanic[titanic['pclass'] == 1]['age'].mean()
avg_age_3rd = titanic[titanic['pclass'] == 3]['age'].mean()

print(f"Average age 1st Class: {avg_age_1st:.1f}")
print(f"Average age 3rd Class: {avg_age_3rd:.1f}")
# Out:
# Average age 1st Class: 39.2
# Average age 3rd Class: 24.8

# %% [markdown]
# **Answer:**

# %% [markdown]
# ### Question 4: Gender Distribution
#
# Were there more male or female passengers?

# %%
# Your code here
print(titanic['sex'].value_counts())
# Out:
# sex
# male      843
# female    466
# Name: count, dtype: int64

# %% [markdown]
# **Answer:**

# %% [markdown]
# ### Question 5: Fare Comparison
#
# Did survivors pay more on average than non-survivors?

# %%
# Your code here
avg_fare_survived = titanic[titanic['survived'] == 1]['fare'].mean()
avg_fare_died = titanic[titanic['survived'] == 0]['fare'].mean()

print(f"Avg fare (Survived): ${avg_fare_survived:.2f}")
print(f"Avg fare (Died): ${avg_fare_died:.2f}")
# Out:
# Avg fare (Survived): $49.36
# Avg fare (Died): $23.35

# %% [markdown]
# **Answer:**

# %% [markdown]
# ---
#
# ## Submission Checklist
#
# - [ ] Completed all exercises
# - [ ] Run all cells successfully
# - [ ] Added name and date at top
# - [ ] Answered all questions
# - [ ] Saved as `dbAppsTask02TrackA.ipynb`
# - [ ] Pushed to GitHub
#
# **Next lesson: We'll move this data into SQL!**
